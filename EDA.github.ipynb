# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# ## Data visualization integration

# %%
df = pd.read_csv(r'C:\Users\fayis\Downloads\Fruit-Prices-2022.csv')
df
# Out:
#                          Fruit    Form  RetailPrice RetailPriceUnit  Yield  \
# 0                       Apples   Fresh       1.8541       per pound   0.90
# 1           Apples, applesauce  Canned       1.1705       per pound   1.00
# 2       Apples, ready-to-drink   Juice       0.8699        per pint   1.00
# 3   Apples, frozen concentrate   Juice       0.6086        per pint   1.00
# 4                     Apricots   Fresh       3.6162       per pound   0.93
# ..                         ...     ...          ...             ...    ...
# 57                 Raspberries   Fresh       7.7338       per pound   0.96
# 58                 Raspberries  Frozen       6.1590       per pound   1.00
# 59                Strawberries   Fresh       2.9682       per pound   0.94
# 60                Strawberries  Frozen       3.3421       per pound   1.00
# 61                  Watermelon   Fresh       0.3820       per pound   0.52
#
#     CupEquivalentSize CupEquivalentUnit  CupEquivalentPrice
# ...

# %%
df['RetailPrice'].hist()
# Out:
# <Axes: >

# %%
df.boxplot(column=['RetailPrice', 'Yield'])
# Out:
# <Axes: >

# %%
df.plot.scatter(x='Yield', y ='RetailPrice')
# Out:
# <Axes: xlabel='Yield', ylabel='RetailPrice'>

# %%
df.plot.line()
# Out:
# <Axes: >

# %%
df['Yield'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Yield'>

# %% [markdown]
# ## Statistical analysis

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.corr()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
df.dtypes
# Out:
# Fruit                  object
# Form                   object
# RetailPrice           float64
# RetailPriceUnit        object
# Yield                 float64
# CupEquivalentSize     float64
# CupEquivalentUnit      object
# CupEquivalentPrice    float64
# dtype: object

# %%
df.cov()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.cov()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:10859, in DataFrame.cov(self, min_periods, ddof, numeric_only)
#   10857 cols = data.columns
#   10858 idx = cols.copy()
# > 10859 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10861 if notna(mat).all():
#   10862     if min_periods is not None and min_periods > len(mat):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
df.iloc[0:5]
# Out:
#                         Fruit    Form  RetailPrice RetailPriceUnit  Yield  \
# 0                      Apples   Fresh       1.8541       per pound   0.90
# 1          Apples, applesauce  Canned       1.1705       per pound   1.00
# 2      Apples, ready-to-drink   Juice       0.8699        per pint   1.00
# 3  Apples, frozen concentrate   Juice       0.6086        per pint   1.00
# 4                    Apricots   Fresh       3.6162       per pound   0.93
#
#    CupEquivalentSize CupEquivalentUnit  CupEquivalentPrice
# 0             0.2425            pounds              0.4996
# 1             0.5401            pounds              0.6323
# 2             8.0000      fluid ounces              0.4349
# 3             8.0000      fluid ounces              0.3043
# 4             0.3638            pounds              1.4145

# %%
data =df['RetailPrice'].astype(int),df['Yield'].astype(int)
data
# Out:
# (0     1
#  1     1
#  2     0
#  3     0
#  4     3
#       ..
#  57    7
#  58    6
#  59    2
#  60    3
#  61    0
#  Name: RetailPrice, Length: 62, dtype: int32,
#  0     0
#  1     1
#  2     1
#  3     1
#  4     0
#       ..
#  57    0
#  58    1
#  59    0
#  60    1
#  61    0
#  Name: Yield, Length: 62, dtype: int32)

# %%
data
# Out:
# (0     1
#  1     1
#  2     0
#  3     0
#  4     3
#       ..
#  57    7
#  58    6
#  59    2
#  60    3
#  61    0
#  Name: RetailPrice, Length: 62, dtype: int32,
#  0     0
#  1     1
#  2     1
#  3     1
#  4     0
#       ..
#  57    0
#  58    1
#  59    0
#  60    1
#  61    0
#  Name: Yield, Length: 62, dtype: int32)

# %%
data.corr()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 data.corr()
#
# AttributeError: 'tuple' object has no attribute 'corr'

# %%
print(type(data))
# Out:
# <class 'tuple'>

# %%
df1 = data[0]

# %%
correlation_matrix = df1.corr()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 correlation_matrix = df1.corr()
#
# TypeError: Series.corr() missing 1 required positional argument: 'other'
